# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
df=pd.read_csv('C:/Users/srika/Desktop/BOOK1.csv')
df
# Out:
#      Termid   Regd No   Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 0    218192   1128776   QPN111    A+      74     NaN      NaN     81.0
# 1    218192   1128776   QPN112     O      69    42.0     85.0      NaN
# 2    218192   1128776   QPN113     A      89    38.0     73.0      NaN
# 3    218192   1128776   QPN114    A+      97     NaN      NaN     82.0
# 4    218192   1128776   QPN115    A+      84    34.0     92.0      NaN
# 5    218192   1128776   QPN116     A      82    19.0     72.0      NaN
# 6    218192   1128776   QPN117    A+      85    48.0     75.0      NaN
# 7    218192   1128776   QPN118    B+      85    37.0     60.0      NaN
# 8    218192   1128776    QPN38     B      47    16.0     44.0      NaN
# 9    218192   1128776    QPN39     A      59     NaN      NaN     74.0
# 10   218192   1128776   QPN110     B      49    32.0     48.0      NaN
# 11   218192   1128776   QPN111     A      68     NaN      NaN     67.0
# 12   218192   1128776   QPN112    B+      65    27.0     46.0      NaN
# 13   218192   1128776   QPN114     A      84     NaN      NaN     74.0
# 14   218192   1128776   QPN115    B+      65    32.0     69.0      NaN
# 15   218192   1128776   QPN116     B      74    10.0     49.0      NaN
# 16   218192   1128776   QPN244    B+      64    32.0     69.0      NaN
# 17   218192   1128776    QPN38     E      41    15.0     20.0      NaN
# 18   218192   1128776    QPN39    B+      55     NaN      NaN     60.0
# 19   218192   1128776   QPN558     E      67    19.0      0.0      NaN
# 20   218192   1128776   QPN777    B+      63    27.0     70.0      NaN
# 21   218192   1128776   QPN110    A+      90    44.0     73.0      NaN
# 22   218192   1128776   QPN111     A      64     NaN      NaN     72.0
# 23   218192   1128776   QPN112     B      59    18.0     45.0      NaN
# 24   218192   1128776   QPN114     A      85     NaN      NaN     72.0
# 25   218192   1128776   QPN115    B+      70    27.0     66.0      NaN
# 26   218192   1128776   QPN116     B      85    19.0     33.0      NaN
# 27   218192   1128776   QPN117     C      37    24.0     53.0      NaN
# 28   218192   1128776   QPN118    B+      80    33.0     53.0      NaN
# 29   218192   1128776    QPN38     B      50    16.0     43.0      NaN
# ..      ...       ...      ...   ...     ...     ...      ...      ...
# 162  218192  10957776  QPN1329    A+      95    30.0     78.0      NaN
# 163  218192  10957776  QPN1330    A+      80    39.0     88.0      NaN
# 164  218192  10957776  QPN1331     A      76     NaN      NaN     66.0
# 165  218192  10957776  QPN1332     A      87    30.0     79.0      NaN
# 166  218192  10957776    QPN28    A+      78    34.0     78.0      NaN
# 167  218192  10957776   QPN328    A+      80    34.0     86.0      NaN
# 168  218192  12549776  QPN1327     C      60    20.0     45.0      NaN
# 169  218192  12549776  QPN1328    B+      62    27.0     66.0      NaN
# 170  218192  12549776  QPN1329     E      34    17.0     23.0      NaN
# 171  218192  12549776  QPN1330     C      67    28.0     50.0      NaN
# 172  218192  12549776  QPN1331     A      71     NaN      NaN     87.0
# 173  218192  12549776  QPN1332     C      67     9.0     43.0      NaN
# 174  218192  12549776    QPN28     D      39    10.0     57.0      NaN
# 175  218192  12549776   QPN328     C      77    14.0     45.0      NaN
# 176  218192  14678776  QPN1327    B+      82    19.0     52.0      NaN
# 177  218192  14678776  QPN1328    B+      52    32.0     63.0      NaN
# 178  218192  14678776  QPN1329     C      42    27.0     50.0      NaN
# 179  218192  14678776  QPN1330     B      77    32.0     58.0      NaN
# 180  218192  14678776  QPN1331    A+      84     NaN      NaN     90.0
# 181  218192  14678776  QPN1332     B      79    20.0     62.0      NaN
# 182  218192  14678776    QPN28    B+      64    32.0     64.0      NaN
# 183  218192  14678776   QPN328    B+      75    24.0     56.0      NaN
# 184  218192  15242776  QPN1327     C      55     8.0     56.0      NaN
# 185  218192  15242776  QPN1328    B+      57    32.0     56.0      NaN
# 186  218192  15242776  QPN1329     C      44    22.0     50.0      NaN
# 187  218192  15242776  QPN1330     A      65    34.0     75.0      NaN
# 188  218192  15242776  QPN1331     O      87     NaN      NaN     92.0
# 189  218192  15242776  QPN1332    B+      95    17.0     62.0      NaN
# 190  218192  15242776    QPN28     A      60    34.0     75.0      NaN
# 191  218192  15242776   QPN328    B+      95    18.0     56.0      NaN
#
#      Course_Att                                         MHRDName  ...  CA_3  \
# 0            87  Bachelor of Technology (Automobile Engineering)  ...     3
# 1            85  Bachelor of Technology (Automobile Engineering)  ...     9
# 2            83  Bachelor of Technology (Automobile Engineering)  ...     7
# 3            96  Bachelor of Technology (Automobile Engineering)  ...    26
# 4            86  Bachelor of Technology (Automobile Engineering)  ...    12
# 5            83  Bachelor of Technology (Automobile Engineering)  ...     4
# 6            84  Bachelor of Technology (Automobile Engineering)  ...    10
# 7            97  Bachelor of Technology (Automobile Engineering)  ...    44
# 8            86  Bachelor of Technology (Automobile Engineering)  ...     7
# 9            88  Bachelor of Technology (Automobile Engineering)  ...     3
# 10           90  Bachelor of Technology (Automobile Engineering)  ...     6
# 11          100  Bachelor of Technology (Automobile Engineering)  ...    29
# 12           93  Bachelor of Technology (Automobile Engineering)  ...    20
# 13           83  Bachelor of Technology (Automobile Engineering)  ...     2
# 14           93  Bachelor of Technology (Automobile Engineering)  ...    10
# 15           92  Bachelor of Technology (Automobile Engineering)  ...     5
# 16           90  Bachelor of Technology (Automobile Engineering)  ...     8
# 17           88  Bachelor of Technology (Automobile Engineering)  ...     4
# 18           83  Bachelor of Technology (Automobile Engineering)  ...     0
# 19           77  Bachelor of Technology (Automobile Engineering)  ...     6
# 20           92  Bachelor of Technology (Automobile Engineering)  ...     8
# 21          100  Bachelor of Technology (Automobile Engineering)  ...     1
# 22           94  Bachelor of Technology (Automobile Engineering)  ...    22
# 23           98  Bachelor of Technology (Automobile Engineering)  ...    11
# 24           96  Bachelor of Technology (Automobile Engineering)  ...    10
# 25           98  Bachelor of Technology (Automobile Engineering)  ...     0
# 26           96  Bachelor of Technology (Automobile Engineering)  ...    23
# 27           91  Bachelor of Technology (Automobile Engineering)  ...     0
# 28           82  Bachelor of Technology (Automobile Engineering)  ...     1
# 29           93  Bachelor of Technology (Automobile Engineering)  ...    10
# ..          ...                                              ...  ...   ...
# 162         100  Bachelor of Technology (Automobile Engineering)  ...     3
# 163         100  Bachelor of Technology (Automobile Engineering)  ...     2
# 164         100  Bachelor of Technology (Automobile Engineering)  ...     2
# 165         100  Bachelor of Technology (Automobile Engineering)  ...     1
# 166         100  Bachelor of Technology (Automobile Engineering)  ...     3
# 167         100  Bachelor of Technology (Automobile Engineering)  ...     9
# 168          69  Bachelor of Technology (Automobile Engineering)  ...     7
# 169          72  Bachelor of Technology (Automobile Engineering)  ...     6
# 170          67  Bachelor of Technology (Automobile Engineering)  ...     3
# 171          64  Bachelor of Technology (Automobile Engineering)  ...     0
# 172          67  Bachelor of Technology (Automobile Engineering)  ...     3
# 173          63  Bachelor of Technology (Automobile Engineering)  ...    12
# 174          69  Bachelor of Technology (Automobile Engineering)  ...     1
# 175          71  Bachelor of Technology (Automobile Engineering)  ...    10
# 176          79  Bachelor of Technology (Automobile Engineering)  ...     5
# 177          79  Bachelor of Technology (Automobile Engineering)  ...     8
# 178          75  Bachelor of Technology (Automobile Engineering)  ...     9
# 179          69  Bachelor of Technology (Automobile Engineering)  ...    30
# 180          80  Bachelor of Technology (Automobile Engineering)  ...    41
# 181          80  Bachelor of Technology (Automobile Engineering)  ...    11
# 182          86  Bachelor of Technology (Automobile Engineering)  ...    10
# 183          84  Bachelor of Technology (Automobile Engineering)  ...     8
# 184          82  Bachelor of Technology (Automobile Engineering)  ...     2
# 185          91  Bachelor of Technology (Automobile Engineering)  ...     1
# 186          79  Bachelor of Technology (Automobile Engineering)  ...     5
# 187          85  Bachelor of Technology (Automobile Engineering)  ...     1
# 188          96  Bachelor of Technology (Automobile Engineering)  ...     0
# 189          80  Bachelor of Technology (Automobile Engineering)  ...     5
# 190          86  Bachelor of Technology (Automobile Engineering)  ...     2
# 191          84  Bachelor of Technology (Automobile Engineering)  ...    36
#
#      CA_4  Height  Weight  ScholarType  Direction  Gender    Medium  \
# 0       0     180      83      Hostler      South  Female  Regional
# 1       5     180      83      Hostler      South  Female  Regional
# 2      23     180      83      Hostler      South  Female  Regional
# 3       6     180      83      Hostler      South  Female  Regional
# 4      23     180      83      Hostler      South  Female  Regional
# 5      24     180      83      Hostler      South  Female  Regional
# 6       9     180      83      Hostler      South  Female  Regional
# 7      21     180      83      Hostler      South  Female  Regional
# 8       3     180      83      Hostler      South  Female  Regional
# 9       8     180      83      Hostler      South  Female  Regional
# 10      0     158      51      Hostler       West    Male     Hindi
# 11     31     158      51      Hostler       West    Male     Hindi
# 12     27     158      51      Hostler       West    Male     Hindi
# 13      1     158      51      Hostler       West    Male     Hindi
# 14     15     158      51      Hostler       West    Male     Hindi
# 15      1     158      51      Hostler       West    Male     Hindi
# 16     14     158      51      Hostler       West    Male     Hindi
# 17      1     158      51      Hostler       West    Male     Hindi
# 18      3     158      51      Hostler       West    Male     Hindi
# 19      0     158      51      Hostler       West    Male     Hindi
# 20     16     158      51      Hostler       West    Male     Hindi
# 21     10     180      90      Hostler       West  Female  Regional
# 22     32     180      90      Hostler       West  Female  Regional
# 23     10     180      90      Hostler       West  Female  Regional
# 24     25     180      90      Hostler       West  Female  Regional
# 25      1     180      90      Hostler       West  Female  Regional
# 26     12     180      90      Hostler       West  Female  Regional
# 27      1     180      90      Hostler       West  Female  Regional
# 28      1     180      90      Hostler       West  Female  Regional
# 29      7     180      90      Hostler       West  Female  Regional
# ..    ...     ...     ...          ...        ...     ...       ...
# 162     5     179      47      Hostler      North    Male   English
# 163    17     179      47      Hostler      North    Male   English
# 164     5     179      47      Hostler      North    Male   English
# 165     0     179      47      Hostler      North    Male   English
# 166     1     179      47      Hostler      North    Male   English
# 167     0     179      47      Hostler      North    Male   English
# 168    35     182      77  Day Scholar       East    Male     Hindi
# 169    25     182      77  Day Scholar       East    Male     Hindi
# 170     8     182      77  Day Scholar       East    Male     Hindi
# 171     2     182      77  Day Scholar       East    Male     Hindi
# 172    48     182      77  Day Scholar       East    Male     Hindi
# 173     3     182      77  Day Scholar       East    Male     Hindi
# 174    24     182      77  Day Scholar       East    Male     Hindi
# 175    44     182      77  Day Scholar       East    Male     Hindi
# 176    17     155      74      Hostler       East    Male  Regional
# 177    12     155      74      Hostler       East    Male  Regional
# 178    19     155      74      Hostler       East    Male  Regional
# 179    10     155      74      Hostler       East    Male  Regional
# 180    22     155      74      Hostler       East    Male  Regional
# 181    19     155      74      Hostler       East    Male  Regional
# 182     2     155      74      Hostler       East    Male  Regional
# 183     2     155      74      Hostler       East    Male  Regional
# 184    32     161      47  Day Scholar      North  Female  Regional
# 185     9     161      47  Day Scholar      North  Female  Regional
# 186     0     161      47  Day Scholar      North  Female  Regional
# 187    19     161      47  Day Scholar      North  Female  Regional
# 188     0     161      47  Day Scholar      North  Female  Regional
# 189     1     161      47  Day Scholar      North  Female  Regional
# 190     1     161      47  Day Scholar      North  Female  Regional
# 191     6     161      47  Day Scholar      North  Female  Regional
#
#     CourseType ProgramType
# 0       Theory          UG
# 1       Theory          UG
# 2       Theory          UG
# 3       Theory          UG
# 4       Theory          UG
# 5       Theory          UG
# 6       Theory          UG
# 7       Theory          UG
# 8       Theory          UG
# 9       Theory          UG
# 10      Theory          UG
# 11      Theory          UG
# 12      Theory          UG
# 13      Theory          UG
# 14      Theory          UG
# 15      Theory          UG
# 16      Theory          UG
# 17      Theory          UG
# 18      Theory          UG
# 19      Theory          UG
# 20      Theory          UG
# 21      Theory          UG
# 22      Theory          UG
# 23      Theory          UG
# 24      Theory          UG
# 25      Theory          UG
# 26      Theory          UG
# 27      Theory          UG
# 28      Theory          UG
# 29      Theory          UG
# ..         ...         ...
# 162     Theory          UG
# 163     Theory          UG
# 164     Theory          UG
# 165     Theory          UG
# 166     Theory          UG
# 167     Theory          UG
# 168     Theory          UG
# 169     Theory          UG
# 170     Theory          UG
# 171     Theory          UG
# 172     Theory          UG
# 173     Theory          UG
# 174     Theory          UG
# 175     Theory          UG
# 176     Theory          UG
# 177     Theory          UG
# 178     Theory          UG
# 179     Theory          UG
# 180     Theory          UG
# 181     Theory          UG
# 182     Theory          UG
# 183     Theory          UG
# 184     Theory          UG
# 185     Theory          UG
# 186     Theory          UG
# 187     Theory          UG
# 188     Theory          UG
# 189     Theory          UG
# 190     Theory          UG
# 191     Theory          UG
#
# [192 rows x 22 columns]

# %%
print('Rows :'+str(df.shape[0]))
print('Columns :'+str(df.shape[1]))
print(df['MHRDName'].value_counts())
# Out:
# Rows :192
# Columns :22
# Bachelor of Technology (Automobile Engineering)    192
# Name: MHRDName, dtype: int64

# %%
df=df[df['MHRDName']=="Bachelor of Technology (Automobile Engineering)"]

# %%
print("Rows :"+str(df.shape[0]))
print("Columns :"+str(df.shape[1]))
# Out:
# Rows :192
# Columns :22

# %% [markdown]
# # DATA PREPROCESSING

# %%
df.head(10)
# Out:
#    Termid  Regd No  Course Grade  CA_100  MTT_50  ETT_100  ETP_100  \
# 0  218192  1128776  QPN111    A+      74     NaN      NaN     81.0
# 1  218192  1128776  QPN112     O      69    42.0     85.0      NaN
# 2  218192  1128776  QPN113     A      89    38.0     73.0      NaN
# 3  218192  1128776  QPN114    A+      97     NaN      NaN     82.0
# 4  218192  1128776  QPN115    A+      84    34.0     92.0      NaN
# 5  218192  1128776  QPN116     A      82    19.0     72.0      NaN
# 6  218192  1128776  QPN117    A+      85    48.0     75.0      NaN
# 7  218192  1128776  QPN118    B+      85    37.0     60.0      NaN
# 8  218192  1128776   QPN38     B      47    16.0     44.0      NaN
# 9  218192  1128776   QPN39     A      59     NaN      NaN     74.0
#
#    Course_Att                                         MHRDName  ...  CA_3  \
# 0          87  Bachelor of Technology (Automobile Engineering)  ...     3
# 1          85  Bachelor of Technology (Automobile Engineering)  ...     9
# 2          83  Bachelor of Technology (Automobile Engineering)  ...     7
# 3          96  Bachelor of Technology (Automobile Engineering)  ...    26
# 4          86  Bachelor of Technology (Automobile Engineering)  ...    12
# 5          83  Bachelor of Technology (Automobile Engineering)  ...     4
# 6          84  Bachelor of Technology (Automobile Engineering)  ...    10
# 7          97  Bachelor of Technology (Automobile Engineering)  ...    44
# 8          86  Bachelor of Technology (Automobile Engineering)  ...     7
# 9          88  Bachelor of Technology (Automobile Engineering)  ...     3
#
#    CA_4  Height  Weight  ScholarType  Direction  Gender    Medium CourseType  \
# 0     0     180      83      Hostler      South  Female  Regional     Theory
# 1     5     180      83      Hostler      South  Female  Regional     Theory
# 2    23     180      83      Hostler      South  Female  Regional     Theory
# 3     6     180      83      Hostler      South  Female  Regional     Theory
# 4    23     180      83      Hostler      South  Female  Regional     Theory
# 5    24     180      83      Hostler      South  Female  Regional     Theory
# 6     9     180      83      Hostler      South  Female  Regional     Theory
# 7    21     180      83      Hostler      South  Female  Regional     Theory
# 8     3     180      83      Hostler      South  Female  Regional     Theory
# 9     8     180      83      Hostler      South  Female  Regional     Theory
#
#   ProgramType
# 0          UG
# 1          UG
# 2          UG
# 3          UG
# 4          UG
# 5          UG
# 6          UG
# 7          UG
# 8          UG
# 9          UG
#
# [10 rows x 22 columns]

# %%
df.drop(['Termid','Regd No','MHRDName', 'CA_1', 'CA_2','CA_3','CA_4','Height','Weight','ScholarType','Direction','CourseType','ProgramType','Medium' ],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    Course Grade  CA_100  MTT_50  ETT_100  ETP_100  Course_Att  Gender
# 0  QPN111    A+      74     NaN      NaN     81.0          87  Female
# 1  QPN112     O      69    42.0     85.0      NaN          85  Female
# 2  QPN113     A      89    38.0     73.0      NaN          83  Female
# 3  QPN114    A+      97     NaN      NaN     82.0          96  Female
# 4  QPN115    A+      84    34.0     92.0      NaN          86  Female

# %%
df.describe()
# Out:
#            CA_100      MTT_50     ETT_100   ETP_100  Course_Att
# count  192.000000  156.000000  156.000000  36.00000  192.000000
# mean    67.609375   27.006410   59.076923  73.50000   83.713542
# std     21.727694   11.025774   21.597950  17.30483   12.850173
# min      0.000000    0.000000    0.000000   0.00000    3.000000
# 25%     59.000000   20.000000   49.000000  66.75000   79.000000
# 50%     72.000000   28.000000   63.500000  73.50000   86.000000
# 75%     82.000000   34.000000   73.000000  86.25000   92.000000
# max    100.000000   50.000000   98.000000  94.00000  100.000000

# %%
grade_map={'O':10,'A+':9,'A':8,'B+':7,'B':6,'C':5,'D':4,'E':3,'F':2}
df['Grade']=df['Grade'].map(grade_map)
df['Grade']
# Out:
# 0       9
# 1      10
# 2       8
# 3       9
# 4       9
# 5       8
# 6       9
# 7       7
# 8       6
# 9       8
# 10      6
# 11      8
# 12      7
# 13      8
# 14      7
# 15      6
# 16      7
# 17      3
# 18      7
# 19      3
# 20      7
# 21      9
# 22      8
# 23      6
# 24      8
# 25      7
# 26      6
# 27      5
# 28      7
# 29      6
#        ..
# 162     9
# 163     9
# 164     8
# 165     8
# 166     9
# 167     9
# 168     5
# 169     7
# 170     3
# 171     5
# 172     8
# 173     5
# 174     4
# 175     5
# 176     7
# 177     7
# 178     5
# 179     6
# 180     9
# 181     6
# 182     7
# 183     7
# 184     5
# 185     7
# 186     5
# 187     8
# 188    10
# 189     7
# 190     8
# 191     7
# Name: Grade, Length: 192, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Course']=le.fit_transform(df['Course'])
df['Gender']=le.fit_transform(df['Gender'])
df.head(5)
# Out:
#    Course  Grade  CA_100  MTT_50  ETT_100  ETP_100  Course_Att  Gender
# 0       1      9      74     NaN      NaN     81.0          87       0
# 1       2     10      69    42.0     85.0      NaN          85       0
# 2       3      8      89    38.0     73.0      NaN          83       0
# 3       4      9      97     NaN      NaN     82.0          96       0
# 4       5      9      84    34.0     92.0      NaN          86       0

# %%
print(df.isnull().sum())
# Out:
# Course          0
# Grade           0
# CA_100          0
# MTT_50         36
# ETT_100        36
# ETP_100       156
# Course_Att      0
# Gender          0
# dtype: int64

# %%
print("Eliminating the null values")
from sklearn.preprocessing import Imputer
#im=Imputer(strategy='mean',missing_values=np.nan)
im=Imputer(missing_values=np.nan,strategy='mean',axis=0)
df['MTT_50']=im.fit_transform(df[['MTT_50']].values)
df['ETT_100']=im.fit_transform(df[['ETT_100']].values)
df['ETP_100']=im.fit_transform(df[['ETP_100']].values)

print(df.isnull().sum())
# Out:
# Eliminating the null values
# Course        0
# Grade         0
# CA_100        0
# MTT_50        0
# ETT_100       0
# ETP_100       0
# Course_Att    0
# Gender        0
# dtype: int64
# C:\Users\srika\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
df.head(5)
# Out:
#    Course  Grade  CA_100    MTT_50    ETT_100  ETP_100  Course_Att  Gender
# 0       1      9      74  27.00641  59.076923     81.0          87       0
# 1       2     10      69  42.00000  85.000000     73.5          85       0
# 2       3      8      89  38.00000  73.000000     73.5          83       0
# 3       4      9      97  27.00641  59.076923     82.0          96       0
# 4       5      9      84  34.00000  92.000000     73.5          86       0

# %% [markdown]
# # ANALYSING DATA

# %%
sea.countplot(x="Gender", data=df)
df['Gender'].value_counts()
# Out:
# 1    115
# 0     77
# Name: Gender, dtype: int64

# %%
sea.countplot(x="Grade", data=df)
df['Grade'].value_counts()
# Out:
# 7     50
# 8     36
# 9     28
# 6     26
# 10    18
# 5     16
# 2      8
# 3      7
# 4      3
# Name: Grade, dtype: int64

# %%
sea.countplot(x="Grade",hue='Gender',data=df)

# %%
df["MTT_50"].plot.hist()

# %%
df["ETT_100"].plot.hist()

# %%
df["ETP_100"].plot.hist()

# %%
df["CA_100"].plot.hist()

# %%
sea.countplot(x="Grade", hue="Gender", data=df)

# %% [markdown]
# # Train,Test&Accuracy

# %%
df.drop(['Gender'],axis=1,inplace=True)
df.tail(5)
# Out:
#      Course  Grade  CA_100    MTT_50    ETT_100  ETP_100  Course_Att
# 187      12      8      65  34.00000  75.000000     73.5          85
# 188      13     10      87  27.00641  59.076923     92.0          96
# 189      14      7      95  17.00000  62.000000     73.5          80
# 190      18      8      60  34.00000  75.000000     73.5          86
# 191      19      7      95  18.00000  56.000000     73.5          84

# %%
data=df.drop('Grade', axis = 1)
target=df['Grade']
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
data=sc.fit_transform(data)
# Out:
# C:\Users\srika\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\srika\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data,target,test_size=0.3,random_state=0)

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
print("Accuracy score :")
print(accuracy_score(y_test,y_pred))
# Out:
# Accuracy score :
# 0.5517241379310345

# %% [markdown]
# # SVM Classifier

# %%
from sklearn.svm import SVC

# %%
model=SVC(C=10,kernel='rbf',gamma='auto')
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score
print('Accuracy Score :')
print(accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score :
# 0.5517241379310345

# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()
gnb.fit(X_train,y_train)
y_pred=gnb.predict(X_test)
print("Accuracy Score :")
print(accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score :
# 0.27586206896551724

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
de=DecisionTreeClassifier(criterion='gini')
de.fit(X_train,y_train)
y_pred=de.predict(X_test)
print("Accuracy Score :")
print(accuracy_score(y_pred,y_test))
# comparing actual response values (y_test) with predicted response values (y_pred)
# Out:
# Accuracy Score :
# 0.5517241379310345

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100,criterion='gini',max_features=5)
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.5

# %%
print("Comparing the  accuracy values attained from the  above models, SVM is best model for the given dataset ")
# Out:
# Comparing the  accuracy values attained from the  above models, SVM is best model for the given dataset

# %%
print("Calculating statistics of dataset provided in order to define the difficulty level of this course ..")
maximum_grade = np.max(target)
minimum_grade = np.min(target)
mean_grade= np.mean(target)
print("Maximum grade: {}".format(maximum_grade))
print("Minimum grade: {}".format(minimum_grade)) 
print("Mean grade: {}".format(mean_grade))
diff=(mean_grade)*10
# Out:
# Calculating statistics of dataset provided in order to define the difficulty level of this course ..
# Maximum grade: 10
# Minimum grade: 2
# Mean grade: 7.057291666666667

# %%
print("Difficulty level of this course (Bachelor of Technology Automobile Engineering) whose accuracy value is {} is :".format(diff))
level=['Easy','Medium','Hard']
if diff<50:
    diff=level[0]
elif diff>50 and diff<75:
    diff=level[1]
else :
    diff=level[2]

print(diff)
# Out:
# Difficulty level of this course (Bachelor of Technology Automobile Engineering) whose accuracy value is 70.57291666666667 is :
# Medium
